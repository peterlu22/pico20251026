# %%
print("hello,python!")
# Out:
# hello,python!

# %%
n1 = 5 + 10
n2 = 20 - 15
print(n1)
print(n2)
# Out:
# 15
# 5

# %%
x1 = 5
x2 = 5.0
x3 = '5.0'
x4 = "5.0"
x5 = True
print(type(x1))
print(type(x2))
print(type(x3))
print(type(x4))
print(type(x5))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
apple = 5
orange = 10
print('apple有' + str(apple) + '個，oragin有' + str(orange) +'個')
print(f'apple有{apple}個，orange有{orange}個')
# Out:
# apple有5個，oragin有10個
# apple有5個，orange有10個
